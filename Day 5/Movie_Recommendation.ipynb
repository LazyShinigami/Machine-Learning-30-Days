# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %%
ratings
# Out:
#          userId  movieId  rating     timestamp
# 0             1      296     5.0  1.147880e+09
# 1             1      306     3.5  1.147869e+09
# 2             1      307     5.0  1.147869e+09
# 3             1      665     5.0  1.147879e+09
# 4             1      899     3.5  1.147869e+09
# ...         ...      ...     ...           ...
# 3033674   20032     1198     4.0  9.976863e+08
# 3033675   20032     1206     4.0  9.962589e+08
# 3033676   20032     1265     3.0  9.962597e+08
# 3033677   20032     1580     4.0  9.962602e+08
# 3033678   20032     1721     2.0           NaN
#
# [3033679 rows x 4 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   title    62423 non-null  object
#  2   genres   62423 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
import re

# method to clean up the movie titles - get rid of anything that's not a space, letter, or number
def clean_title(title):
  return re.sub('[^a-zA-Z0-9 ]', '', title)

movies['clean_title'] = movies['title'].apply(clean_title)
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
#                             clean_title
# 0                        Toy Story 1995
# 1                          Jumanji 1995
# 2                 Grumpier Old Men 1995
# 3                Waiting to Exhale 1995
# 4      Father of the Bride Part II 1995
# ...                                 ...
# 62418                           We 2018
# 62419           Window of the Soul 2001
# 62420                    Bad Poems 2018
# 62421                 A Girl Thing 2001
# 62422       Women of Devils Island 1962
#
# [62423 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range = (1,2)) # compares similarities - oversimplified explanation

tfidf = vectorizer.fit_transform(movies['clean_title'])
# dir(vectorizer)
# temp = list(vectorizer.vocabulary_)
# temp
# Out:
# ['toy',
#  'story',
#  '1995',
#  'toy story',
#  'story 1995',
#  'jumanji',
#  'jumanji 1995',
#  'grumpier',
#  'old',
#  'men',
#  'grumpier old',
#  'old men',
#  'men 1995',
#  'waiting',
#  'to',
#  'exhale',
#  'waiting to',
#  'to exhale',
#  'exhale 1995',
#  'father',
#  'of',
#  'the',
#  'bride',
#  'part',
#  'ii',
#  'father of',
#  'of the',
#  'the bride',
#  'bride part',
#  'part ii',
#  'ii 1995',
#  'heat',
#  'heat 1995',
#  'sabrina',
#  'sabrina 1995',
#  'tom',
#  'and',
#  'huck',
#  'tom and',
#  'and huck',
#  'huck 1995',
#  'sudden',
#  'death',
#  'sudden death',
#  'death 1995',
#  'goldeneye',
#  'goldeneye 1995',
#  'american',
#  'president',
#  'american president',
#  'president the',
#  'the 1995',
#  'dracula',
#  'dead',
#  'loving',
#  'it',
#  'dracula dead',
#  'dead and',
#  'and loving',
#  'loving it',
#  'it 1995',
#  'balto',
#  'balto 1995',
#  'nixon',
#  'nixon 1995',
#  'cutthroat',
#  'island',
#  'cutthroat island',
#  'island 1995',
#  'casino',
#  'casino 1995',
#  'sense',
#  'sensibility',
#  'sense and',
#  'and sensibility',
#  'sensibility 1995',
#  'four',
#  'rooms',
#  'four rooms',
#  'rooms 1995',
#  'ace',
#  'ventura',
#  'when',
#  'nature',
#  'calls',
#  'ace ventura',
#  'ventura when',
#  'when nature',
#  'nature calls',
#  'calls 1995',
#  'money',
#  'train',
#  'money train',
#  'train 1995',
#  'get',
#  'shorty',
#  'get shorty',
#  'shorty 1995',
#  'copycat',
#  'copycat 1995',
#  'assassins',
#  'assassins 1995',
#  'powder',
#  'powder 1995',
#  'leaving',
#  'las',
#  'vegas',
#  'leaving las',
#  'las vegas',
#  'vegas 1995',
#  'othello',
#  'othello 1995',
#  'now',
#  'then',
#  'now and',
#  'and then',
#  'then 1995',
#  'persuasion',
#  'persuasion 1995',
#  'city',
#  'lost',
#  'children',
#  'cit',
#  'des',
#  'enfants',
#  'perdus',
#  'la',
#  'city of',
#  'of lost',
#  'lost children',
#  'children the',
#  'the cit',
#  'cit des',
#  'des enfants',
#  'enfants perdus',
#  'perdus la',
#  'la 1995',
#  'shanghai',
#  'triad',
#  'yao',
#  'dao',
#  'waipo',
#  'qiao',
#  'shanghai triad',
#  'triad yao',
#  'yao yao',
#  'yao dao',
#  'dao waipo',
#  'waipo qiao',
#  'qiao 1995',
#  'dangerous',
#  'minds',
#  'dangerous minds',
#  'minds 1995',
#  'twelve',
#  'monkeys',
#  'aka',
#  '12',
#  'twelve monkeys',
#  'monkeys aka',
#  'aka 12',
#  '12 monkeys',
#  'monkeys 1995',
#  'wings',
#  'courage',
#  'wings of',
#  'of courage',
#  'courage 1995',
#  'babe',
#  'babe 1995',
#  'carrington',
#  'carrington 1995',
#  'man',
#  'walking',
#  'dead man',
#  'man walking',
#  'walking 1995',
#  'across',
#  'sea',
#  'time',
#  'across the',
#  'the sea',
#  'sea of',
#  'of time',
#  'time 1995',
#  'takes',
#  'two',
#  'it takes',
#  'takes two',
#  'two 1995',
#  'clueless',
#  'clueless 1995',
#  'cry',
#  'beloved',
#  'country',
#  'cry the',
#  'the beloved',
#  'beloved country',
#  'country 1995',
#  'richard',
#  'iii',
#  'richard iii',
#  'iii 1995',
#  'presidents',
#  'dead presidents',
#  'presidents 1995',
#  'restoration',
#  'restoration 1995',
#  'mortal',
#  'kombat',
#  'mortal kombat',
#  'kombat 1995',
#  'die',
#  'for',
#  'to die',
#  'die for',
#  'for 1995',
#  'how',
#  'make',
#  'an',
#  'quilt',
#  'how to',
#  'to make',
#  'make an',
#  'an american',
#  'american quilt',
#  'quilt 1995',
#  'seven',
#  'se7en',
#  'seven aka',
#  'aka se7en',
#  'se7en 1995',
#  'pocahontas',
#  'pocahontas 1995',
#  'night',
#  'is',
#  'falling',
#  'when night',
#  'night is',
#  'is falling',
#  'falling 1995',
#  'usual',
#  'suspects',
#  'usual suspects',
#  'suspects the',
#  'guardian',
#  'angel',
#  '1994',
#  'guardian angel',
#  'angel 1994',
#  'mighty',
#  'aphrodite',
#  'mighty aphrodite',
#  'aphrodite 1995',
#  'lamerica',
#  'lamerica 1994',
#  'big',
#  'green',
#  'big green',
#  'green the',
#  'georgia',
#  'georgia 1995',
#  'kids',
#  'round',
#  'table',
#  'kids of',
#  'the round',
#  'round table',
#  'table 1995',
#  'home',
#  'holidays',
#  'home for',
#  'for the',
#  'the holidays',
#  'holidays 1995',
#  'postman',
#  'postino',
#  'il',
#  'postman the',
#  'the postino',
#  'postino il',
#  'il 1994',
#  'confessional',
#  'confessionnal',
#  'le',
#  'confessional the',
#  'the confessionnal',
#  'confessionnal le',
#  'le 1995',
#  'indian',
#  'in',
#  'cupboard',
#  'indian in',
#  'in the',
#  'the cupboard',
#  'cupboard the',
#  'eye',
#  '1996',
#  'eye for',
#  'for an',
#  'an eye',
#  'eye 1996',
#  'mr',
#  'hollands',
#  'opus',
#  'mr hollands',
#  'hollands opus',
#  'opus 1995',
#  'dont',
#  'be',
#  'menace',
#  'south',
#  'central',
#  'while',
#  'drinking',
#  'your',
#  'juice',
#  'hood',
#  'dont be',
#  'be menace',
#  'menace to',
#  'to south',
#  'south central',
#  'central while',
#  'while drinking',
#  'drinking your',
#  'your juice',
#  'juice in',
#  'the hood',
#  'hood 1996',
#  'if',
#  'by',
#  'two if',
#  'if by',
#  'by sea',
#  'sea 1996',
#  'biodome',
#  'biodome 1996',
#  'lawnmower',
#  'beyond',
#  'cyberspace',
#  'lawnmower man',
#  'man beyond',
#  'beyond cyberspace',
#  'cyberspace 1996',
#  'bits',
#  'two bits',
#  'bits 1995',
#  'french',
#  'twist',
#  'gazon',
#  'maudit',
#  'french twist',
#  'twist gazon',
#  'gazon maudit',
#  'maudit 1995',
#  'friday',
#  'friday 1995',
#  'from',
#  'dusk',
#  'till',
#  'dawn',
#  'from dusk',
#  'dusk till',
#  'till dawn',
#  'dawn 1996',
#  'fair',
#  'game',
#  'fair game',
#  'game 1995',
#  'kicking',
#  'screaming',
#  'kicking and',
#  'and screaming',
#  'screaming 1995',
#  'misrables',
#  'les',
#  'misrables les',
#  'les 1995',
#  'bed',
#  'roses',
#  'bed of',
#  'of roses',
#  'roses 1996',
#  'bully',
#  'big bully',
#  'bully 1996',
#  'screamers',
#  'screamers 1995',
#  'nico',
#  'icon',
#  'nico icon',
#  'icon 1995',
#  'crossing',
#  'guard',
#  'crossing guard',
#  'guard the',
#  'juror',
#  'juror the',
#  'the 1996',
#  'white',
#  'balloon',
#  'badkonake',
#  'sefid',
#  'white balloon',
#  'balloon the',
#  'the badkonake',
#  'badkonake sefid',
#  'sefid 1995',
#  'things',
#  'do',
#  'denver',
#  'youre',
#  'things to',
#  'to do',
#  'do in',
#  'in denver',
#  'denver when',
#  'when youre',
#  'youre dead',
#  'dead 1995',
#  'antonias',
#  'line',
#  'antonia',
#  'antonias line',
#  'line antonia',
#  'antonia 1995',
#  'once',
#  'upon',
#  'we',
#  'were',
#  'colored',
#  'once upon',
#  'upon time',
#  'time when',
#  'when we',
#  'we were',
#  'were colored',
#  'colored 1995',
#  'last',
#  'summer',
#  'hamptons',
#  'last summer',
#  'summer in',
#  'the hamptons',
#  'hamptons 1995',
#  'angels',
#  'insects',
#  'angels and',
#  'and insects',
#  'insects 1995',
#  'squall',
#  'white squall',
#  'squall 1996',
#  'dunston',
#  'checks',
#  'dunston checks',
#  'checks in',
#  'in 1996',
#  'black',
#  'sheep',
#  'black sheep',
#  'sheep 1996',
#  'nick',
#  'nick of',
#  'journey',
#  'august',
#  'king',
#  'the journey',
#  'journey of',
#  'of august',
#  'august king',
#  'king 1995',
#  'mary',
#  'reilly',
#  'mary reilly',
#  'reilly 1996',
#  'vampire',
#  'brooklyn',
#  'vampire in',
#  'in brooklyn',
#  'brooklyn 1995',
#  'beautiful',
#  'girls',
#  'beautiful girls',
#  'girls 1996',
#  'broken',
#  'arrow',
#  'broken arrow',
#  'arrow 1996',
#  'bleak',
#  'midwinter',
#  'the bleak',
#  'bleak midwinter',
#  'midwinter 1995',
#  'hate',
#  'haine',
#  'hate haine',
#  'haine la',
#  'shopping',
#  'shopping 1994',
#  'heidi',
#  'fleiss',
#  'hollywood',
#  'madam',
#  'heidi fleiss',
#  'fleiss hollywood',
#  'hollywood madam',
#  'madam 1995',
#  'hall',
#  'city hall',
#  'hall 1996',
#  'bottle',
#  'rocket',
#  'bottle rocket',
#  'rocket 1996',
#  'wrong',
#  'mr wrong',
#  'wrong 1996',
#  'unforgettable',
#  'unforgettable 1996',
#  'happy',
#  'gilmore',
#  'happy gilmore',
#  'gilmore 1996',
#  'bridges',
#  'madison',
#  'county',
#  'bridges of',
#  'of madison',
#  'madison county',
#  'county the',
#  'nobody',
#  'loves',
#  'me',
#  'keiner',
#  'liebt',
#  'mich',
#  'nobody loves',
#  'loves me',
#  'me keiner',
#  'keiner liebt',
#  'liebt mich',
#  'mich 1994',
#  'muppet',
#  'treasure',
#  'muppet treasure',
#  'treasure island',
#  'island 1996',
#  'catwalk',
#  'catwalk 1996',
#  'headless',
#  'body',
#  'topless',
#  'bar',
#  'headless body',
#  'body in',
#  'in topless',
#  'topless bar',
#  'bar 1995',
#  'braveheart',
#  'braveheart 1995',
#  'taxi',
#  'driver',
#  '1976',
#  'taxi driver',
#  'driver 1976',
#  'rumble',
#  'bronx',
#  'hont',
#  'faan',
#  'kui',
#  'rumble in',
#  'the bronx',
#  'bronx hont',
#  'hont faan',
#  'faan kui',
#  'kui 1995',
#  'before',
#  'after',
#  'before and',
#  'and after',
#  'after 1996',
#  'margarets',
#  'museum',
#  'margarets museum',
#  'museum 1995',
#  'happiness',
#  'field',
#  'bonheur',
#  'est',
#  'dans',
#  'pr',
#  'happiness is',
#  'is in',
#  'the field',
#  'field bonheur',
#  'bonheur est',
#  'est dans',
#  'dans le',
#  'le pr',
#  'pr le',
#  'anne',
#  'frank',
#  'remembered',
#  'anne frank',
#  'frank remembered',
#  'remembered 1995',
#  'young',
#  'poisoners',
#  'handbook',
#  'young poisoners',
#  'poisoners handbook',
#  'handbook the',
#  'lucy',
#  'fell',
#  'if lucy',
#  'lucy fell',
#  'fell 1996',
#  'steal',
#  'little',
#  'steal big',
#  'big steal',
#  'steal little',
#  'little 1995',
#  'race',
#  'sun',
#  'race the',
#  'the sun',
#  'sun 1996',
#  'boys',
#  'st',
#  'vincent',
#  '1992',
#  'boys of',
#  'of st',
#  'st vincent',
#  'vincent the',
#  'the 1992',
#  'boomerang',
#  'boomerang 1992',
#  'chungking',
#  'express',
#  'chung',
#  'hing',
#  'sam',
#  'lam',
#  'chungking express',
#  'express chung',
#  'chung hing',
#  'hing sam',
#  'sam lam',
#  'lam 1994',
#  'star',
#  'maker',
#  'uomo',
#  'delle',
#  'stelle',
#  'star maker',
#  'maker the',
#  'the uomo',
#  'uomo delle',
#  'delle stelle',
#  'stelle 1995',
#  'flirting',
#  'with',
#  'disaster',
#  'flirting with',
#  'with disaster',
#  'disaster 1996',
#  'neverending',
#  'neverending story',
#  'story iii',
#  'iii the',
#  'the 1994',
#  'silences',
#  'palace',
#  'saimt',
#  'el',
#  'qusur',
#  'silences of',
#  'the palace',
#  'palace the',
#  'the saimt',
#  'saimt el',
#  'el qusur',
#  'qusur 1994',
#  'jupiters',
#  'wife',
#  'jupiters wife',
#  'wife 1994',
#  'pie',
#  'sky',
#  'pie in',
#  'the sky',
#  'sky 1996',
#  'angela',
#  'angela 1995',
#  'frankie',
#  'starlight',
#  'frankie starlight',
#  'starlight 1995',
#  'jade',
#  'jade 1995',
#  'nueba',
#  'yol',
#  'nueba yol',
#  'yol 1995',
#  'sonic',
#  'outlaws',
#  'sonic outlaws',
#  'outlaws 1995',
#  'down',
#  'periscope',
#  'down periscope',
#  'periscope 1996',
#  'journals',
#  'jean',
#  'seberg',
#  'from the',
#  'the journals',
#  'journals of',
#  'of jean',
#  'jean seberg',
#  'seberg 1995',
#  'year',
#  'man of',
#  'the year',
#  'year 1995',
#  'neon',
#  'bible',
#  'neon bible',
#  'bible the',
#  'target',
#  'target 1995',
#  'up',
#  'close',
#  'personal',
#  'up close',
#  'close and',
#  'and personal',
#  'personal 1996',
#  'birdcage',
#  'birdcage the',
#  'shadows',
#  'cienie',
#  '1988',
#  'shadows cienie',
#  'cienie 1988',
#  'gospa',
#  'gospa 1995',
#  'brothers',
#  'mcmullen',
#  'brothers mcmullen',
#  'mcmullen the',
#  'bad',
#  'bad boys',
#  'boys 1995',
#  'amazing',
#  'panda',
#  'adventure',
#  'amazing panda',
#  'panda adventure',
#  'adventure the',
#  'basketball',
#  'diaries',
#  'basketball diaries',
#  'diaries the',
#  'awfully',
#  'awfully big',
#  'big adventure',
#  'adventure an',
#  'an 1995',
#  'amateur',
#  'amateur 1994',
#  'apollo',
#  '13',
#  'apollo 13',
#  '13 1995',
#  'rob',
#  'roy',
#  'rob roy',
#  'roy 1995',
#  'addiction',
#  'addiction the',
#  'batman',
#  'forever',
#  'batman forever',
#  'forever 1995',
#  'beauty',
#  'day',
#  'belle',
#  'de',
#  'jour',
#  '1967',
#  'beauty of',
#  'the day',
#  'day belle',
#  'belle de',
#  'de jour',
#  'jour 1967',
#  'rangoon',
#  'beyond rangoon',
#  'rangoon 1995',
#  'blue',
#  'face',
#  'blue in',
#  'the face',
#  'face 1995',
#  'canadian',
#  'bacon',
#  'canadian bacon',
#  'bacon 1995',
#  'casper',
#  'casper 1995',
#  'clockers',
#  'clockers 1995',
#  'congo',
#  'congo 1995',
#  'crimson',
#  'tide',
#  'crimson tide',
#  'tide 1995',
#  'crumb',
#  'crumb 1994',
#  'desperado',
#  'desperado 1995',
#  'devil',
#  'dress',
#  'devil in',
#  'in blue',
#  'blue dress',
#  'dress 1995',
#  'hard',
#  'vengeance',
#  'die hard',
#  'hard with',
#  'with vengeance',
#  'vengeance 1995',
#  'doom',
#  'generation',
#  'doom generation',
#  'generation the',
#  'feast',
#  'july',
#  'feast of',
#  'of july',
#  'july 1995',
#  'first',
#  'knight',
#  'first knight',
#  'knight 1995',
#  'free',
#  'willy',
#  'free willy',
#  'willy the',
#  'the adventure',
#  'adventure home',
#  'home 1995',
#  'hackers',
#  'hackers 1995',
#  'jeffrey',
#  'jeffrey 1995',
#  'johnny',
#  'mnemonic',
#  'johnny mnemonic',
#  'mnemonic 1995',
#  'judge',
#  'dredd',
#  'judge dredd',
#  'dredd 1995',
#  'jury',
#  'duty',
#  'jury duty',
#  'duty 1995',
#  'kids 1995',
#  'living',
#  'oblivion',
#  'living in',
#  'in oblivion',
#  'oblivion 1995',
#  'lord',
#  'illusions',
#  'lord of',
#  'of illusions',
#  'illusions 1995',
#  'love',
#  'human',
#  'remains',
#  '1993',
#  'love human',
#  'human remains',
#  'remains 1993',
#  'mad',
#  'mad love',
#  'love 1995',
#  'mallrats',
#  'mallrats 1995',
#  'morphin',
#  'power',
#  'rangers',
#  'movie',
#  'mighty morphin',
#  'morphin power',
#  'power rangers',
#  'rangers the',
#  'the movie',
#  'movie 1995',
#  'moonlight',
#  'valentino',
#  'moonlight and',
#  'and valentino',
#  'valentino 1995',
#  'mute',
#  'witness',
#  'mute witness',
#  'witness 1994',
#  'nadja',
#  'nadja 1994',
#  'net',
#  'net the',
#  'nine',
#  'months',
#  'nine months',
#  'months 1995',
#  'party',
#  'girl',
#  'party girl',
#  'girl 1995',
#  'prophecy',
#  'prophecy the',
#  'reckless',
#  'reckless 1995',
#  'safe',
#  'safe 1995',
#  'scarlet',
#  'letter',
#  'scarlet letter',
#  'letter the',
#  'show',
#  'the show',
#  'show 1995',
#  'showgirls',
#  'showgirls 1995',
#  'smoke',
#  'smoke 1995',
#  'something',
#  'talk',
#  'about',
#  'something to',
#  'to talk',
#  'talk about',
#  'about 1995',
#  'species',
#  'species 1995',
#  'stars',
#  'on',
#  'henrietta',
#  'stars fell',
#  'fell on',
#  'on henrietta',
#  'henrietta the',
#  'strange',
#  'days',
#  'strange days',
#  'days 1995',
#  'umbrellas',
#  'cherbourg',
#  'parapluies',
#  '1964',
#  'umbrellas of',
#  'of cherbourg',
#  'cherbourg the',
#  'the parapluies',
#  'parapluies de',
#  'de cherbourg',
#  'cherbourg les',
#  'les 1964',
#  'tie',
#  'that',
#  'binds',
#  'tie that',
#  'that binds',
#  'binds the',
#  'three',
#  'wishes',
#  'three wishes',
#  'wishes 1995',
#  'total',
#  'eclipse',
#  'total eclipse',
#  'eclipse 1995',
#  'wong',
#  'foo',
#  'thanks',
#  'everything',
#  'julie',
#  'newmar',
#  'to wong',
#  'wong foo',
#  ...]

# %%
from sklearn.metrics.pairwise import cosine_similarity
# cosine_similarity compares HOW similar are two texts by comparing the angle between their vectors:
# same direction - more similar
# opposite direction - less similar

import numpy as np

def search(title):
  title = clean_title(title)
  query_vec = vectorizer.transform([title])
  similarity = cosine_similarity(query_vec, tfidf).flatten()
  indices = np.argpartition(similarity, -5)[-5:]
  results = movies.iloc[indices][::-1]
  return results

# %%
# interactive search box - just a prototype, the final version is at the end
import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value = 'Toy Story',
    description = 'Movie Title: ',
    disabled = False
)

movie_list = widgets.Output()

def on_type(data):
  with movie_list:
    movie_list.clear_output()
    # print('weeeeeeeeeee', data)
    title = data['new']
    if len(title) > 5:
      display(search(title))


movie_input.observe(on_type, names = 'value')

display(movie_input, movie_list)
# Out:
# Text(value='Toy Story', description='Movie Title: ')
# Output()

# %%
# finding users who liked the movie we've searched for
movie_id = 1
similar_users = ratings[(ratings['movieId'] == movie_id) & (ratings['rating'] >= 5)]['userId'].unique()
similar_users
# Out:
# array([   36,    75,    86, ..., 20001, 20009, 20023])

# %%
# finding what other movies those users (similar users) liked
similar_user_recs = ratings[(ratings['userId'].isin(similar_users)) & (ratings['rating'] >= 4)]['movieId']

# converting it into % so it is easier to understand and compare
similar_user_recs = similar_user_recs.value_counts() / len(similar_users)

# keeping records of only where the % is more than 25% (can be any number - the more the better but the fewer the results get)
similar_user_recs = similar_user_recs[similar_user_recs > 0.25]

# %%
# similar_user_recs.sort_values(ascending = False)
# finding how much did everyone else like the shortlisted movies
all_users = ratings[(ratings['movieId'].isin(similar_user_recs.index)) & (ratings['rating'] >= 4)]

# turning it into % so we can compare how much a user similar to us liked the movie vs how the average user liked it
all_user_recs = all_users['movieId'].value_counts() / len(all_users['userId'].unique())

# %%
rec_pct = pd.concat([similar_user_recs, all_user_recs], axis = 1)
rec_pct.columns = ['similar', 'all']
rec_pct
# Out:
#           similar       all
# movieId
# 1        1.000000  0.248045
# 318      0.509265  0.459750
# 260      0.501494  0.337111
# 356      0.482367  0.387709
# 296      0.447101  0.408300
# 593      0.433951  0.379675
# 1210     0.402271  0.255227
# 1196     0.401076  0.287204
# 588      0.399283  0.159617
# 480      0.395099  0.231019
# 589      0.389719  0.256824
# 1270     0.386133  0.219846
# 457      0.385535  0.229795
# 1198     0.382546  0.269274
# 3114     0.377167  0.104655
# 364      0.375374  0.173078
# 150      0.372983  0.202181
# 2571     0.367603  0.363554
# 527      0.367005  0.319926
# 50       0.360430  0.300346
# 608      0.344292  0.235435
# 110      0.337119  0.267837
# 595      0.328751  0.128758
# 47       0.312612  0.249002
# 858      0.304244  0.279755
# 2028     0.298267  0.221655
# 1197     0.295876  0.183081
# 32       0.294082  0.203405
# 1265     0.291094  0.162703
# 2762     0.289898  0.215270
# 34       0.288105  0.112477
# 780      0.273162  0.133333
# 4886     0.272564  0.144187
# 1291     0.272564  0.172918
# 1240     0.265392  0.163501
# 380      0.264196  0.129875
# 4993     0.261207  0.267944
# 4306     0.261207  0.168981
# 2858     0.260610  0.261027
# 1580     0.259414  0.131258
# 1036     0.258219  0.162171
# 2959     0.253437  0.305241
# 1136     0.253437  0.188880

# %%
# we're looking for a big differential between similar and all columns of rec_pct dataframe
# for example you searched for Avengers, if 100% of people who liked it also liked Toy Story, it doesn't mean they're similar.
# it just means that everyone liked it - not a good recommendation
# on the other hand if 100% of the people who like Avengers also liked Thor, and on average only 40% of people liked Thor,
# it indicated that people of similar tastes like that movie so it's likely similar
# we'll call this differential 'score'

rec_pct['score'] = rec_pct['similar'] / rec_pct['all']
rec_pct = rec_pct.sort_values('score', ascending = False)

# %%
# now we actually need the title of these movies
varx = rec_pct.merge(movies, left_index = True, right_on = 'movieId')
varx
# Out:
#        similar       all     score  movieId  \
# 0     1.000000  0.248045  4.031532        1
# 3021  0.377167  0.104655  3.603889     3114
# 33    0.288105  0.112477  2.561465       34
# 587   0.328751  0.128758  2.553252      595
# 580   0.399283  0.159617  2.501506      588
# 359   0.375374  0.173078  2.168812      364
# 764   0.273162  0.133333  2.048715      780
# 375   0.264196  0.129875  2.034234      380
# 1523  0.259414  0.131258  1.976364     1580
# 4780  0.272564  0.144187  1.890349     4886
# 148   0.372983  0.202181  1.844792      150
# 1232  0.291094  0.162703  1.789113     1265
# 1237  0.386133  0.219846  1.756380     1270
# 475   0.395099  0.231019  1.710244      480
# 452   0.385535  0.229795  1.677733      457
# 1207  0.265392  0.163501  1.623180     1240
# 1167  0.295876  0.183081  1.616095     1197
# 1013  0.258219  0.162171  1.592264     1036
# 1258  0.272564  0.172918  1.576260     1291
# 1179  0.402271  0.255227  1.576129     1210
# 4201  0.261207  0.168981  1.545779     4306
# 581   0.389719  0.256824  1.517458      589
# 257   0.501494  0.337111  1.487624      260
# 600   0.344292  0.235435  1.462364      608
# 31    0.294082  0.203405  1.445797       32
# 1168  0.382546  0.269274  1.420660     1198
# 1166  0.401076  0.287204  1.396484     1196
# 2670  0.289898  0.215270  1.346673     2762
# 1939  0.298267  0.221655  1.345636     2028
# 1108  0.253437  0.188880  1.341788     1136
# 108   0.337119  0.267837  1.258671      110
# 46    0.312612  0.249002  1.255458       47
# 351   0.482367  0.387709  1.244145      356
# 49    0.360430  0.300346  1.200051       50
# 522   0.367005  0.319926  1.147159      527
# 585   0.433951  0.379675  1.142952      593
# 314   0.509265  0.459750  1.107700      318
# 292   0.447101  0.408300  1.095030      296
# 840   0.304244  0.279755  1.087536      858
# 2480  0.367603  0.363554  1.011137     2571
# 2766  0.260610  0.261027  0.998402     2858
# 4887  0.261207  0.267944  0.974860     4993
# 2867  0.253437  0.305241  0.830285     2959
#
#                                                   title  \
# 0                                      Toy Story (1995)
# 3021                                 Toy Story 2 (1999)
# 33                                          Babe (1995)
# 587                         Beauty and the Beast (1991)
# 580                                      Aladdin (1992)
# 359                               Lion King, The (1994)
# 764                Independence Day (a.k.a. ID4) (1996)
# 375                                    True Lies (1994)
# 1523                   Men in Black (a.k.a. MIB) (1997)
# 4780                              Monsters, Inc. (2001)
# 148                                    Apollo 13 (1995)
# 1232                               Groundhog Day (1993)
# 1237                          Back to the Future (1985)
# 475                                Jurassic Park (1993)
# 452                                Fugitive, The (1993)
# 1207                             Terminator, The (1984)
# 1167                         Princess Bride, The (1987)
# 1013                                    Die Hard (1988)
# 1258          Indiana Jones and the Last Crusade (1989)
# 1179  Star Wars: Episode VI - Return of the Jedi (1983)
# 4201                                       Shrek (2001)
# 581                   Terminator 2: Judgment Day (1991)
# 257           Star Wars: Episode IV - A New Hope (1977)
# 600                                        Fargo (1996)
# 31            Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 1168  Raiders of the Lost Ark (Indiana Jones and the...
# 1166  Star Wars: Episode V - The Empire Strikes Back...
# 2670                            Sixth Sense, The (1999)
# 1939                         Saving Private Ryan (1998)
# 1108             Monty Python and the Holy Grail (1975)
# 108                                   Braveheart (1995)
# 46                          Seven (a.k.a. Se7en) (1995)
# 351                                 Forrest Gump (1994)
# 49                           Usual Suspects, The (1995)
# 522                             Schindler's List (1993)
# 585                    Silence of the Lambs, The (1991)
# 314                    Shawshank Redemption, The (1994)
# 292                                 Pulp Fiction (1994)
# 840                               Godfather, The (1972)
# 2480                                 Matrix, The (1999)
# 2766                             American Beauty (1999)
# 4887  Lord of the Rings: The Fellowship of the Ring,...
# 2867                                  Fight Club (1999)
#
#                                                  genres  \
# 0           Adventure|Animation|Children|Comedy|Fantasy
# 3021        Adventure|Animation|Children|Comedy|Fantasy
# 33                                       Children|Drama
# 587     Animation|Children|Fantasy|Musical|Romance|IMAX
# 580         Adventure|Animation|Children|Comedy|Musical
# 359     Adventure|Animation|Children|Drama|Musical|IMAX
# 764                    Action|Adventure|Sci-Fi|Thriller
# 375            Action|Adventure|Comedy|Romance|Thriller
# 1523                               Action|Comedy|Sci-Fi
# 4780        Adventure|Animation|Children|Comedy|Fantasy
# 148                                Adventure|Drama|IMAX
# 1232                             Comedy|Fantasy|Romance
# 1237                            Adventure|Comedy|Sci-Fi
# 475                    Action|Adventure|Sci-Fi|Thriller
# 452                                            Thriller
# 1207                             Action|Sci-Fi|Thriller
# 1167            Action|Adventure|Comedy|Fantasy|Romance
# 1013                              Action|Crime|Thriller
# 1258                                   Action|Adventure
# 1179                            Action|Adventure|Sci-Fi
# 4201  Adventure|Animation|Children|Comedy|Fantasy|Ro...
# 581                                       Action|Sci-Fi
# 257                             Action|Adventure|Sci-Fi
# 600                         Comedy|Crime|Drama|Thriller
# 31                              Mystery|Sci-Fi|Thriller
# 1168                                   Action|Adventure
# 1166                            Action|Adventure|Sci-Fi
# 2670                               Drama|Horror|Mystery
# 1939                                   Action|Drama|War
# 1108                           Adventure|Comedy|Fantasy
# 108                                    Action|Drama|War
# 46                                     Mystery|Thriller
# 351                            Comedy|Drama|Romance|War
# 49                               Crime|Mystery|Thriller
# 522                                           Drama|War
# 585                               Crime|Horror|Thriller
# 314                                         Crime|Drama
# 292                         Comedy|Crime|Drama|Thriller
# 840                                         Crime|Drama
# 2480                             Action|Sci-Fi|Thriller
# 2766                                      Drama|Romance
# 4887                                  Adventure|Fantasy
# 2867                        Action|Crime|Drama|Thriller
#
#                                             clean_title
# 0                                        Toy Story 1995
# 3021                                   Toy Story 2 1999
# 33                                            Babe 1995
# 587                           Beauty and the Beast 1991
# 580                                        Aladdin 1992
# 359                                  Lion King The 1994
# 764                       Independence Day aka ID4 1996
# 375                                      True Lies 1994
# 1523                          Men in Black aka MIB 1997
# 4780                                  Monsters Inc 2001
# 148                                      Apollo 13 1995
# 1232                                 Groundhog Day 1993
# 1237                            Back to the Future 1985
# 475                                  Jurassic Park 1993
# 452                                   Fugitive The 1993
# 1207                                Terminator The 1984
# 1167                            Princess Bride The 1987
# 1013                                      Die Hard 1988
# 1258            Indiana Jones and the Last Crusade 1989
# 1179      Star Wars Episode VI  Return of the Jedi 1983
# 4201                                         Shrek 2001
# 581                      Terminator 2 Judgment Day 1991
# 257               Star Wars Episode IV  A New Hope 1977
# 600                                          Fargo 1996
# 31                   Twelve Monkeys aka 12 Monkeys 1995
# 1168  Raiders of the Lost Ark Indiana Jones and the ...
# 1166  Star Wars Episode V  The Empire Strikes Back 1980
# 2670                               Sixth Sense The 1999
# 1939                           Saving Private Ryan 1998
# 1108               Monty Python and the Holy Grail 1975
# 108                                     Braveheart 1995
# 46                                 Seven aka Se7en 1995
# 351                                   Forrest Gump 1994
# 49                              Usual Suspects The 1995
# 522                                Schindlers List 1993
# 585                       Silence of the Lambs The 1991
# 314                       Shawshank Redemption The 1994
# 292                                   Pulp Fiction 1994
# 840                                  Godfather The 1972
# 2480                                    Matrix The 1999
# 2766                               American Beauty 1999
# 4887  Lord of the Rings The Fellowship of the Ring T...
# 2867                                    Fight Club 1999

# %%
# now, we're just putting everything we did above inside a function, so we can reuse it instead
# of using the harcoded movieId = 1 (referencing to cell right after iPyWidgets implemenetation)
def recommender(movieId):
  similar_users = ratings[(ratings['movieId'] == movie_id) & (ratings['rating'] >= 5)]['userId'].unique()
  similar_user_recs = ratings[(ratings['userId'].isin(similar_users)) & (ratings['rating'] >= 4)]['movieId']
  similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
  similar_user_recs = similar_user_recs[similar_user_recs > 0.25]

  all_users = ratings[(ratings['movieId'].isin(similar_user_recs.index)) & (ratings['rating'] >= 4)]
  all_user_recs = all_users['movieId'].value_counts() / len(all_users['userId'].unique())

  rec_pct = pd.concat([similar_user_recs, all_user_recs], axis = 1)
  rec_pct.columns = ['similar', 'all']
  rec_pct['score'] = rec_pct['similar'] / rec_pct['all']
  rec_pct = rec_pct.sort_values('score', ascending = False)

  return rec_pct.merge(movies, left_index = True, right_on = 'movieId')

# %%
# final version of the input widgets and stuff
import ipywidgets as widgets
from IPython.display import display

movie_name_input = widgets.Text(
    value = 'Toy Story',
    description = 'Movie Title: ',
    # disabled = False
)

recommendation_list = widgets.Output()

def on_type(data):
  with recommendation_list:
    recommendation_list.clear_output()
    title = data['new']
    if len(title) > 5:
      results = search(title)
      movie_id = results.iloc[0]['movieId']
      display(recommender(movie_id).head(10))

movie_name_input.observe(on_type, names = 'value')

display(movie_name_input, recommendation_list)
# Out:
# Text(value='Toy Story', description='Movie Title: ')
# Output()
